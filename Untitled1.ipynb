# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set(style="whitegrid")

# %%
df = pd.read_csv("normal_distribution_dataset.csv")

# Display the first few rows of the dataset
df.head()
# Out:
#    Student_ID  Exam_Score  Weight_Apple (g)  Height (cm)  Daily_Sales ($)  \
# 0           1       74.97            136.43       172.79          3415.54
# 1           2       68.62            143.89       172.27          4156.01
# 2           3       76.48            138.05       162.51          4530.38
# 3           4       85.23            152.21       174.64          5119.74
# 4           5       67.66            173.94       158.08          5819.33
#
#    Lifespan_Bulb (hrs)
# 0               976.41
# 1              1050.64
# 2               990.09
# 3              1004.53
# 4              1035.87

# %%
# Select columns to visualize
columns = ["Exam_Score", "Weight_Apple (g)", "Height (cm)", "Daily_Sales ($)", "Lifespan_Bulb (hrs)"]

# Plot
plt.figure(figsize=(15, 10))

for i, col in enumerate(columns, 1):
    plt.subplot(2, 3, i)
    
    # Plot histogram
    sns.histplot(df[col], kde=False, bins=30, color="skyblue", stat="density")
    
    # Fit a normal curve
    mean, std = norm.fit(df[col])
    x = np.linspace(df[col].min(), df[col].max(), 100)
    plt.plot(x, norm.pdf(x, mean, std), color="red")
    
    # Add title
    plt.title(f"{col} Distribution")

# Adjust layout
plt.tight_layout()
plt.show()
